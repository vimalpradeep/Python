# %%
# Print Statement
print("Hope AI")
# Out:
# Hope AI

# %%
#buy input
print(input("Enter your institute Name? : "))
# Out:
# Enter your institute Name? : Hope AI
# Hope AI

# %%
#buy Inputs
print(input("Enter your Name : "))
print(int(input("Enter your Age : ")))
print(input("Enter your School Name : "))  
print(input("Enter your Degree : "))
# Out:
# Enter your Name : Vimal
# Vimal
# Enter your Age : 30
# 30
# Enter your School Name : Higher Secondary
# Higher Secondary
# Enter your Degree : B.Tech I.T
# B.Tech I.T

# %%
#Addition
a = 43
b = 34
Add = a + b
print("a =", a)
print("b =", b)
print("add=",Add)
# Out:
# a = 43
# b = 34
# add= 77

# %%
#Subraction
a = 43
b = 34
sub = a - b
print("a =", a)
print("b =", b)
print("Sub=",sub)
# Out:
# a = 43
# b = 34
# Sub= 9

# %%
#Multiplication
a = 63
b = 97
Mul = a * b
print("a =", a)
print("b =", b)
print("Mul=",Mul)
# Out:
# a = 63
# b = 97
# Mul= 6111

# %%
#Division
a = 76
b = 31
Div = a / b
print("a =", a)
print("b =", b)
print("Div=",Div)
# Out:
# a = 76
# b = 31
# Div= 2.4516129032258065

# %%
#Floor Division
a=76
b=31
FloorDiv = a//b
print("a =", a)
print("b =", b)
print("Floor Div=",FloorDiv)
# Out:
# a = 76
# b = 31
# Floor Div= 2

# %%
#Modulo
a = 76
b = 31
Modulo = a % b
print("a =", a)
print("b =", b)
print("Modulo=",Modulo)
# Out:
# a = 76
# b = 31
# Modulo= 14

# %%
#Power
a = 4
b = 4
Power = a ** b
print("a =", a)
print("b =", b)
print("Power=",Power)
# Out:
# a = 4
# b = 4
# Power= 256
