# %%
from MultipleFunctions import multiplefunction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from MultipleFunctions import multiplefunction
#
# File D:\Hope AI\PYTHON\MultipleFunctions.py:57
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 11,
#       6    "id": "042886b5-1813-496e-96a4-6af3055709e0",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "class multiplefunction():\n",
#      11     "        def Subfields():\n",
#      12     "          Lists= [\"Machine Learning\",\"Neural Networks\",\"Vision\",\"Robotics\",\"Speech Processing\",\"Natural Language Processing\"]\n",
#      13     "          print(\"Sub-fields in AI are:\")\n",
#      14     "          for subfield in Lists:\n",
#      15     "              print(subfield)\n",
#      16     "        def OddEven():\n",
# ...

# %%
multiplefunction.Subfields()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 multiplefunction.Subfields()
#
# NameError: name 'multiplefunction' is not defined
